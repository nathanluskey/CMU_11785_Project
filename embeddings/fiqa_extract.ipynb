# %%
import json
import os
import pandas as pd
import re

# %% [markdown]
# # Connect to my Drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Change the path as required
path = "/content/drive/MyDrive/11785-project"
! cd $path

# %%
train_json_path = ["fiqa2018/FiQA_ABSA_task1/task1_headline_ABSA_train.json", "fiqa2018/FiQA_ABSA_task1/task1_post_ABSA_train.json"]
fiqaPath = os.path.join(path, "fiqa2018/FiQA_ABSA_task1/task1_headline_ABSA_train.json")
fiqaPath = os.path.join(path, "fiqa2018/FiQA_ABSA_task1/task1_post_ABSA_train.json")
with open(fiqaPath) as f:
    data = json.load(f)
    print(len(data))
# Out:
# 675

# %% [markdown]
# # Custom DataExtractor

# %%
class DataExtractor:

    def __init__(self, path, partition="train"):
        self.path = path
        self.fname = path.split('/')[-1]
        self.partition = partition
        if partition == "train":
            self.columns = ["id", "sentence", "snippets", "target", "sentiment_score", "aspects"]
        else:
            self.columns = ["id", "sentence", "snippets", "target"]

    def extract_data(self):
        path = self.path
        partition = self.partition

        with open(path) as f:
            json_data = f.read()
            raw_data = json.loads(json_data)

        data = []
        for id in raw_data:
            sentence = raw_data[id]["sentence"]
            all_info = raw_data[id]["info"]
            for info in all_info:
                row = []
                snippets = info["snippets"][2:-2]
                target = info["target"]
                row.extend([id, sentence, snippets, target])

                if partition == "train":
                    sentiment_score = float(info["sentiment_score"])
                    aspects = info["aspects"][2:-2]
                    row.extend([sentiment_score, aspects])

            data.append(row)

        return data

    def convert_to_df(self, data):
        columns = self.columns
        df = pd.DataFrame(data, columns=columns)
        return df

    def clean_df(self, df):
        df['sentence'] = df['sentence'].apply(lambda x: re.sub(r'http\S+', '', x))
        df['snippets'] = df['snippets'].apply(lambda x: re.sub(r'http\S+', '', x))
        return df

    def write_df(self, df, path = None):
        if path is None:
            path = self.path.replace(".json", ".csv")
        df.to_csv(path)

# %%
train_path1 = os.path.join(path, "fiqa2018/FiQA_ABSA_task1/task1_headline_ABSA_train.json")
de1 = DataExtractor(train_path1)
data1 = de1.extract_data()
df1 = de1.convert_to_df(data1)
df1 = de1.clean_df(df1)
de1.write_df(df1)

# %%
train_path2 = os.path.join(path, "fiqa2018/FiQA_ABSA_task1/task1_post_ABSA_train.json")
de2 = DataExtractor(train_path2)
data2 = de2.extract_data()
df2 = de2.convert_to_df(data2)
df2 = de1.clean_df(df2)
de2.write_df(df2)

# %%
test_path1 = os.path.join(path, "fiqa2018/FIQA_ABSA_task1_test/task1_post_ABSA_test.json")
de3 = DataExtractor(test_path1, "test")
data3 = de3.extract_data()
df3 = de3.convert_to_df(data3)
df3 = de1.clean_df(df3)
de3.write_df(df3)

# %%
test_path2 = os.path.join(path, "fiqa2018/FIQA_ABSA_task1_test/task1_headline_ABSA_test.json")
de4 = DataExtractor(test_path2, "test")
data4 = de4.extract_data()
df4 = de4.convert_to_df(data4)
df4 = de1.clean_df(df4)
de4.write_df(df4)

# %%
df1.head()
# Out:
#    id                                           sentence  \
# 0   1  Royal Mail chairman Donald Brydon set to step ...
# 1   7  Stakes High for AstraZeneca Heart Drug Facing ...
# 2   8  UPDATE 1-Dairy Crest loses a third of Morrison...
# 3  22  Insight hires Aviva's David Hillier for multi-...
# 4  30  Primark racks up a happy Christmas after stron...
#
#                                            snippets sentiment_score  target  \
# 0                                  set to step down      Royal Mail  -0.374
# 1                          Facing Tough Competition     AstraZeneca  -0.240
# 2    Crest loses a third of Morrisons milk contract       Morrisons  -0.161
# 3  hires Aviva's David Hillier for multi-asset team         Insight   0.137
# 4                                after strong sales         Primark   0.704
#
#                                        aspects
# 0                        Corporate/Appointment
# 1                              Corporate/Risks
# 2   Corporate/Sales/Failed Contract Discussion
# 3  Corporate/Appointment/Executive Appointment
# 4                              Corporate/Sales

# %%
df2.head()
# Out:
#       id                                           sentence  \
# 0  14860  Slowly adding some $FIO here but gotta be care...
# 1  14864                      $TRX  Long setup. MACD cross.
# 2  14867  I am not optimistic about $amzn both fundement...
# 3  14875  $GRPN might be selling off ahead of $P earning...
# 4  14876             $IACI  Looks good on the weekly chart.
#
#                                             snippets sentiment_score  target  \
# 0  Slowly adding some $FIO here but gotta be careful             FIO   0.459
# 1                            Long setup. MACD cross.             TRX   0.438
# 2  both fundementals and charts look like poopoo ...            AMZN  -0.506
# 3                         might be selling off ahead               P  -0.202
# 4                    Looks good on the weekly chart.            IACI   0.379
#
#                                        aspects
# 0     Stock/Price Action/Bullish/Bull Position
# 1                     Stock/Technical Analysis
# 2                   Stock/Price Action/Bearish
# 3  Stock/Price Action/Bearish/Bearish Behavior
# 4                     Stock/Technical Analysis

# %%
df3.head()
# Out:
#            id                                           sentence  \
# 0  19167$GILD                              $GILD Back in Bullish
# 1    19168$LE  $LE Back in for a swing on this one @ 15.35/sh...
# 2   19169$WLL           $WLL In for a quarter position @ 8.10...
# 3   19170$VNR  $VNR Just added 2,300 @ .77 Going in for long ...
# 4  19171$TSLA    Bought back into $TSLA, previously sold at $362
#
#                     snippets target
# 0                    Back in   GILD
# 1        Back in for a swing     LE
# 2  In for a quarter position    WLL
# 3           Just added 2,300    VNR
# 4                     Bought   TSLA

# %%
df4.head()
# Out:
#                id                                           sentence  \
# 0     0_Cuadrilla  Cuadrilla files to delay application to frack ...
# 1  1001_Sainsbury  Sainsbury chief warns of squeeze on high stree...
# 2   1006_Barclays  Barclays fined for anti-money-laundering failings
# 3   1007_Barclays  UPDATE 3-Barclays fined for lax crime checks i...
# 4        1014_GSK  GSK aims to file up to 20 new drugs for approv...
#
#                                        snippets     target
# 0                    files to delay application  Cuadrilla
# 1     warns of squeeze on high street retailers  Sainsbury
# 2      fined for anti-money-laundering failings   Barclays
# 3                 fined for lax crime checks in   Barclays
# 4  file up to 20 new drugs for approval by 2020        GSK
